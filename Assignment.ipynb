# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Tanmay Gaba<b>
# <br>Student

# %% [markdown]
# *I am interested in Data Science because playing with data gives me joy. Data has a lot to do with the real world and can also provide us with greater insights so we must try our best ways to deal with it and get something out of it. This part excites me most.*

# %% [markdown]
# ### Next cell gives a simple example of addition of two digits followed by its result.

# %%
1+1
# Out:
# 2

# %% [markdown]
# <hr>

# %% [markdown]
# <ol><li>Name
#     <li>Class
#     <li>Roll no.

# %% [markdown]
# <s>Hello World
